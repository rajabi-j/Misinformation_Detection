# %% [markdown]
# ## Show the Results of Average Matrices Training

# %%
import pickle

results_path = 'model_results_avgerage.pkl'
with open(results_path, 'rb') as file:
    data = pickle.load(file)

for key, value in data.items():
    print(f"\n{key}:")
    if isinstance(value, dict):  # If the value is a dictionary, print its content
        print(f"Best Model Parameters: {value['Best Model Parameters']}")
        print(f"Train F1 Score: {value['Train']['F1 Score']}")
        print(f"Test F1 Score: {value['Test']['F1 Score']}")
# Out:
# G_7:
# Train F1 Score: {'C': 0.1, 'kernel': 'rbf'}
# Train F1 Score: 0.8519436138402392
# Test F1 Score: 0.6908783783783784
#
# S_7:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7616076071614293
# Test F1 Score: 0.7425343018563357
#
# G_8:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7616641901931649
# Test F1 Score: 0.740501212611156
#
# S_8:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7615510325360273
# Test F1 Score: 0.7425343018563357
#
# G_9:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7608163265306123
# Test F1 Score: 0.7425343018563357
#
# S_9:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7616076071614293
# Test F1 Score: 0.7425343018563357
#
# G_10:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7618339897451141
# Test F1 Score: 0.7425343018563357
#
# S_10:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7615510325360273
# Test F1 Score: 0.7425343018563357
#
# G_11:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7622871588965723
# Test F1 Score: 0.740501212611156
#
# S_11:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7616076071614293
# Test F1 Score: 0.7425343018563357
#
# G_12:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.763877505401982
# Test F1 Score: 0.7333333333333333
#
# S_12:
# Train F1 Score: {'C': 0.1, 'kernel': 'rbf'}
# Train F1 Score: 0.8442296277452727
# Test F1 Score: 0.7393126571668064
#
# G_13:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7607598693974473
# Test F1 Score: 0.7425343018563357
#
# S_13:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7616076071614293
# Test F1 Score: 0.7425343018563357
#
# G_14:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7605341246290801
# Test F1 Score: 0.7431340872374798
#
# S_14:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7616076071614293
# Test F1 Score: 0.7425343018563357
#
# G_15:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7597450718838002
# Test F1 Score: 0.7123966942148761
#
# S_15:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.761720781633108
# Test F1 Score: 0.7425343018563357
#
# G_16:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7610422388835276
# Test F1 Score: 0.7425343018563357
#
# S_16:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7616076071614293
# Test F1 Score: 0.7425343018563357
#
# G_17:
# Train F1 Score: {'C': 0.1, 'kernel': 'rbf'}
# Train F1 Score: 0.8476478204574881
# Test F1 Score: 0.691470054446461
#
# S_17:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7612117612117613
# Test F1 Score: 0.7425343018563357
#
# G_18:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7595839524517087
# Test F1 Score: 0.7428571428571429
#
# S_18:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7613248180603001
# Test F1 Score: 0.7425343018563357
#
# G_19:
# Train F1 Score: {'C': 0.01, 'kernel': 'rbf'}
# Train F1 Score: 0.7640482933373081
# Test F1 Score: 0.7250409165302782
#
# S_19:
# Train F1 Score: {'C': 0.1, 'kernel': 'rbf'}
# Train F1 Score: 0.8419073662621774
# Test F1 Score: 0.7201365187713311

# %%
import matplotlib.pyplot as plt

# Extracting Test F1 Scores
x_labels = [i for i in range(7, 20)]
g_scores = [data[f"G_{x}"]["Test"]["F1 Score"] for x in x_labels]
s_scores = [data[f"S_{x}"]["Test"]["F1 Score"] for x in x_labels]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x_labels, g_scores, label='IVA_G', marker='o')
plt.plot(x_labels, s_scores, label='IVA_Spice', marker='s')

plt.title('Test F1 Scores by Model Type')
plt.xlabel('Model Variant')
plt.ylabel('F1 Score')
plt.xticks(x_labels)
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Extracting Test F1 Scores
x_labels = [i for i in range(7, 20)]
g_scores = [data[f"G_{x}"]["Test"]["F1 Score"] for x in x_labels]
s_scores = [data[f"S_{x}"]["Test"]["F1 Score"] for x in x_labels]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x_labels, g_scores, label='IVA_G', marker='o')
plt.plot(x_labels, s_scores, label='IVA_Spice', marker='s')

plt.title('Test F1 Scores by Model Type')
plt.xlabel('Model Variant')
plt.ylabel('F1 Score')
plt.xticks(x_labels)
plt.ylim(.6, .8)
plt.legend()
plt.grid(True)
plt.show()
